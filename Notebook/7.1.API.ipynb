# %%
import requests

url = "https://edamam-food-and-grocery-database.p.rapidapi.com/api/food-database/v2/parser"

querystring = {"nutrition-type":"cooking","category[0]":"generic-foods","health[0]":"alcohol-free"}

headers = {
	"X-RapidAPI-Key": "3ef95bb0abmshbef487fa05415f6p15822ajsn81ba10513887",
	"X-RapidAPI-Host": "edamam-food-and-grocery-database.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
data_json = response.json()

print(data_json)
# Out:
# {'text': '', 'parsed': [], 'hints': [{'food': {'foodId': 'food_bwrgmmqau78xrdazxx79obeezumz', 'uri': 'http://www.edamam.com/ontologies/edamam.owl#Food_01001', 'label': 'Butter, Salted', 'knownAs': 'Butter, salted', 'nutrients': {'ENERC_KCAL': 717.0, 'PROCNT': 0.85, 'FAT': 81.1, 'CHOCDF': 0.06, 'FIBTG': 0.0}, 'category': 'Generic foods', 'categoryLabel': 'food', 'image': 'https://www.edamam.com/food-img/515/515af390107678fce1533a31ee4cc35b.jpeg'}, 'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving', 'label': 'Serving', 'weight': 14.0}, {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_tablespoon', 'label': 'Tablespoon', 'weight': 14.2}, {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_cup', 'label': 'Cup', 'weight': 227.0}, {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_stick', 'label': 'Stick', 'weight': 113.0}, {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram', 'label': 'Gram', 'weight': 1.0}, {'uri
# ...

# %%
import pandas as pd

df = []
for i in data_json['hints']:

    if 'image' in i['food']:
        pass
    else :
        i['food']['image'] = ''

    data_food = {
        'foodId': i['food']['foodId'],
        'label': i['food']['label'],
        'category': i['food']['category'],
        #'foodContentsLabel': i['food']['foodContentsLabel'],
        'image': i['food']['image']
    }
    df.append(data_food)

df = pd.DataFrame(df)
df
# Out:
#                                foodId  \
# 0   food_bwrgmmqau78xrdazxx79obeezumz
# 1   food_blrpqo1bp94h17apq4prgbhcuhex
# 2   food_bzaenytbm02cd4br159f4biv49jc
# 3   food_aqptx2cauhjjzubmplnjna81ev33
# 4   food_au4tus5b092owgbiu8yama5yupfp
# 5   food_a06hreabh7agoeazgrtiobunge7b
# 6   food_bq1kaa2anb8wmsaj3in43bxxsjyh
# 7   food_a8q8p7tahfewtuajrmgcrbpxtti8
# 8
# 9   food_b4g9w0dboo05sdaxwu1n9a3b4emv
# 10  food_a5ylefeb5r30eibjj4mqubdc09z1
# 11  food_abw09jebwny3g6bb7jvn0bbalare
# 12  food_apqi15daozoc8oacpl41rallrou9
# 13  food_b0nmp6gaermj0aad3mf7iararumu
# 14  food_a78om83aro60t5a4wpm8hbf3239s
# 15  food_bowtx9kb5cpt8yb6qswcga80ycli
# 16  food_a5oa9cnaawyx9uang44bka8467or
# 17  food_ax6ocbjas0levpb3nl0n7auzwy0i
# 18  food_ba6vmpsbtteeyabi8t2i8bwzl13d
# 19  food_a9n6dlcb168fzqb5qrkp9a7oy4jp
#
#                                                 label       category  \
# 0                                      Butter, Salted  Generic foods
# ...

# %%
import pandas as pd
import requests

url = "https://edamam-food-and-grocery-database.p.rapidapi.com/api/food-database/v2/parser"

querystring = {
    "ingr": "champagne",
    
}

headers = {
    "X-RapidAPI-Key": "cc334cfad2mshd35cf0470715deap1b3b9cjsnc1bbbb529da0",
    "X-RapidAPI-Host": "edamam-food-and-grocery-database.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

# Convertir la réponse JSON en DataFrame
data = response.json()
df = pd.json_normalize(data['hints'])

# Afficher les premières lignes du DataFrame
df.head(10)
# Out:
#                                             measures  \
# 0  [{'uri': 'http://www.edamam.com/ontologies/eda...
# 1  [{'uri': 'http://www.edamam.com/ontologies/eda...
# 2  [{'uri': 'http://www.edamam.com/ontologies/eda...
# 3  [{'uri': 'http://www.edamam.com/ontologies/eda...
# 4  [{'uri': 'http://www.edamam.com/ontologies/eda...
# 5  [{'uri': 'http://www.edamam.com/ontologies/eda...
# 6  [{'uri': 'http://www.edamam.com/ontologies/eda...
# 7  [{'uri': 'http://www.edamam.com/ontologies/eda...
# 8  [{'uri': 'http://www.edamam.com/ontologies/eda...
# 9  [{'uri': 'http://www.edamam.com/ontologies/eda...
#
#                          food.foodId  \
# 0  food_a656mk2a5dmqb2adiamu6beihduu
# 1  food_b753ithamdb8psbt0w2k9aquo06c
# 2  food_b3dyababjo54xobm6r8jzbghjgqe
# 3  food_a9e0ghsamvoc45bwa2ybsa3gken9
# 4  food_an4jjueaucpus2a3u1ni8auhe7q9
# 5  food_bmu5dmkazwuvpaa5prh1daa8jxs0
# 6  food_alpl44taoyv11ra0lic1qa8xculi
# 7  food_byap67hab6evc3a0f9w1oag3s0qf
# ...

# %%
import pandas as pd
import requests

url = "https://edamam-food-and-grocery-database.p.rapidapi.com/api/food-database/v2/parser"

querystring = {
    "ingr": "champagne",
    
}

headers = {
    "X-RapidAPI-Key": "cc334cfad2mshd35cf0470715deap1b3b9cjsnc1bbbb529da0",
    "X-RapidAPI-Host": "edamam-food-and-grocery-database.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

# Convertir la réponse JSON en DataFrame
data_json = response.json()
df = []
for i in data_json['hints']:

    if 'image' in i['food']:
        pass
    else :
        i['food']['image'] = ''

    data_food = {
        'foodId': i['food']['foodId'],
        'label': i['food']['label'],
        'category': i['food']['category'],
        'foodContentsLabel': i['food']['foodContentsLabel'],
        'image': i['food']['image']
    }
    df.append(data_food)

df = pd.DataFrame(df)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 32
#      25     else :
#      26         i['food']['image'] = ''
#      28     data_food = {
#      29         'foodId': i['food']['foodId'],
#      30         'label': i['food']['label'],
#      31         'category': i['food']['category'],
# ---> 32         'foodContentsLabel': i['food']['foodContentsLabel'],
#      33         'image': i['food']['image']
#      34     }
#      35     df.append(data_food)
#      37 df = pd.DataFrame(df)
#
# KeyError: 'foodContentsLabel'

# %%
data_json
# Out:
# {'text': 'champagne',
#  'parsed': [{'food': {'foodId': 'food_a656mk2a5dmqb2adiamu6beihduu',
#     'uri': 'http://www.edamam.com/ontologies/edamam.owl#Food_table_white_wine',
#     'label': 'Champagne',
#     'knownAs': 'dry white wine',
#     'nutrients': {'ENERC_KCAL': 82.0,
#      'PROCNT': 0.07,
#      'FAT': 0.0,
#      'CHOCDF': 2.6,
#      'FIBTG': 0.0},
#     'category': 'Generic foods',
#     'categoryLabel': 'food',
#     'image': 'https://www.edamam.com/food-img/a71/a718cf3c52add522128929f1f324d2ab.jpg'}}],
#  'hints': [{'food': {'foodId': 'food_a656mk2a5dmqb2adiamu6beihduu',
#     'uri': 'http://www.edamam.com/ontologies/edamam.owl#Food_table_white_wine',
#     'label': 'Champagne',
#     'knownAs': 'dry white wine',
#     'nutrients': {'ENERC_KCAL': 82.0,
#      'PROCNT': 0.07,
#      'FAT': 0.0,
#      'CHOCDF': 2.6,
#      'FIBTG': 0.0},
#     'category': 'Generic foods',
#     'categoryLabel': 'food',
# ...
